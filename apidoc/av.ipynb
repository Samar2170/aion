# %%
import requests
import dotenv
import os

# %%
av_api_key=os.getenv('AV_API_KEY')

# %%
BASE_URL='https://www.alphavantage.co/query?'

# %%
resp=requests.get(BASE_URL+'function=TIME_SERIES_DAILY&symbol=AAPL&apikey='+av_api_key)

# %%
data=resp.json()

# %%
len(data['Time Series (Daily)'])
# Out:
# 100

# %%
resp=requests.get(BASE_URL+'function=TIME_SERIES_DAILY&symbol=KOTAKBANK.BSE&apikey='+av_api_key)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'KOTAKBANK.BSE',
#   '3. Last Refreshed': '2025-03-10',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-03-10': {'1. open': '1939.7000',
#    '2. high': '1939.7000',
#    '3. low': '1918.0000',
#    '4. close': '1921.8000',
#    '5. volume': '11441'},
#   '2025-03-07': {'1. open': '1921.7000',
#    '2. high': '1939.7500',
#    '3. low': '1910.5000',
#    '4. close': '1934.3500',
#    '5. volume': '15421'},
#   '2025-03-06': {'1. open': '1962.9500',
#    '2. high': '1962.9500',
#    '3. low': '1910.5000',
#    '4. close': '1921.6000',
#    '5. volume': '36268'},
#   '2025-03-05': {'1. open': '1913.7500',
#    '2. high': '1953.0000',
#    '3. low': '1895.4500',
#    '4. close': '1940.3000',
#    '5. volume': '1360112'},
#   '2025-03-04': {'1. open': '1911.9500',
#    '2. high': '1915.8000',
#    '3. low': '1898.3500',
# ...

# %%
resp=requests.get(BASE_URL+'function=OVERVIEW&symbol=AAPL&apikey='+av_api_key)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# {'Symbol': 'AAPL',
#  'AssetType': 'Common Stock',
#  'Name': 'Apple Inc',
#  'Description': "Apple Inc. is an American multinational technology company that specializes in consumer electronics, computer software, and online services. Apple is the world's largest technology company by revenue (totalling $274.5 billion in 2020) and, since January 2021, the world's most valuable company. As of 2021, Apple is the world's fourth-largest PC vendor by unit sales, and fourth-largest smartphone manufacturer. It is one of the Big Five American information technology companies, along with Amazon, Google, Microsoft, and Facebook.",
#  'CIK': '320193',
#  'Exchange': 'NASDAQ',
#  'Currency': 'USD',
#  'Country': 'USA',
#  'Sector': 'TECHNOLOGY',
#  'Industry': 'ELECTRONIC COMPUTERS',
#  'Address': 'ONE INFINITE LOOP, CUPERTINO, CA, US',
#  'OfficialSite': 'https://www.apple.com',
#  'FiscalYearEnd': 'September',
#  'LatestQuarter': '2024-12-31',
#  'MarketCapitalization': '3591333741000',
# ...

# %%
resp=requests.get(BASE_URL+'function=INCOME_STATEMENT&symbol=AAPL&apikey='+av_api_key)

# %%
resp.json()
# Out:
# {'symbol': 'AAPL',
#  'annualReports': [{'fiscalDateEnding': '2024-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '180683000000',
#    'totalRevenue': '391035000000',
#    'costOfRevenue': '236449000000',
#    'costofGoodsAndServicesSold': '210352000000',
#    'operatingIncome': '123216000000',
#    'sellingGeneralAndAdministrative': '26097000000',
#    'researchAndDevelopment': '31370000000',
#    'operatingExpenses': '57467000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': 'None',
#    'nonInterestIncome': '391035000000',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': '8200000000',
#    'depreciationAndAmortization': '11445000000',
#    'incomeBeforeTax': '123485000000',
#    'incomeTaxExpense': '29749000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '93736000000',
#    'comprehensiveIncomeNetOfTax': '98016000000',
# ...
